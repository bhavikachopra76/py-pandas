# %%
import pandas as pd

# %%
data = {
    "First name" : ["Bhavika" , "Chaitanya" , "Dharya"],
    "Last name" : ["Chopra" , "Garg" , "Chopra"],
    "Email" : ["bhavikachopra@gmail.com" , "chaitanyagarg@gmail.com", "dharyachopra@gmail.com"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   First name Last name                    Email
# 0    Bhavika    Chopra  bhavikachopra@gmail.com
# 1  Chaitanya      Garg  chaitanyagarg@gmail.com
# 2     Dharya    Chopra   dharyachopra@gmail.com

# %%
#changing index to email
df.set_index('Email' , inplace=True)

# %%
df
# Out:
#                         First name Last name
# Email
# bhavikachopra@gmail.com    Bhavika    Chopra
# chaitanyagarg@gmail.com  Chaitanya      Garg
# dharyachopra@gmail.com      Dharya    Chopra

# %%
#accessing through indexes
df.loc['bhavikachopra@gmail.com']
# Out:
# First name    Bhavika
# Last name      Chopra
# Name: bhavikachopra@gmail.com, dtype: str

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                      Email First name Last name
# 0  bhavikachopra@gmail.com    Bhavika    Chopra
# 1  chaitanyagarg@gmail.com  Chaitanya      Garg
# 2   dharyachopra@gmail.com     Dharya    Chopra
